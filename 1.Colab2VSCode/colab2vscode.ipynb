# %% [markdown]
# # Link Colab to VScode
#
# This is method for connecting Colab to VScode using ssh

# %% [markdown]
# ## instaill colab_ssh
# ### 1 Run code below
# Run code and you can see this output
# ![image.png](attachment:image.png)
#
# ### 2 Copy and paste
# Then you can see this page for copy authorization code
# ![image-2.png](attachment:image-2.png)
# get authorization code and paste it
#
# ### 3 DownLoad colab_ssh
# the output cell will give you a link to get colab_ssh
# ![image-3.png](attachment:image-3.png)
# DownLoad it and move it to the desired folder
# ![image-4.png](attachment:image-4.png)
#
# ### 4 ssh Setting-1
# ![image-5.png](attachment:image-5.png)
# You can see this,
# and open VScode install "Remote-ssh"
# ![image-7.png](attachment:image-7.png)
#
# ### 5 ssh Setting-2
# Open remote control
# "click it!"
# ![image-8.png](attachment:image-8.png)
# And select "Connect to Host"
# ![image-9.png](attachment:image-9.png)
# select "Configure ssh host"
# ![image-11.png](attachment:image-11.png)
# select your config file
# ![image-12.png](attachment:image-12.png)
# ![image-13.png](attachment:image-13.png)
#
# ### 6 ssh Setting-3
# Now back to colab and install "cloudfare" from link and copy the code
# ![image-14.png](attachment:image-14.png)
# And paste it to config file and in ProxyCommand You have to use loacation of "cloudfared.exe"
# ![image-15.png](attachment:image-15.png)
# And Saveit
#
# ### 7 Start remote control
# Now we are ready to connect remotely!!
# copy this code
# ![image-16.png](attachment:image-16.png)
# And paste it on here
# VScode -> remote control -> Connect to Host
# ![image-17.png](attachment:image-17.png)
#
# With New window opening, you have to set something
# "Linux"->"continue"
# and when VScode asking you password, answer is "test"

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Install colab_ssh on google colab
# !pip install colab_ssh --upgrade
from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
launch_ssh_cloudflared(password="test")
# Optional: if you want to clone a github repository
# init_git_cloudflared(githubRepositoryUrl)
# Out:
# Mounted at /content/gdrive
# ...
# <style>
# *{
# 	outline:none;
# }
# code{
# 	display:inline-block;
# 	padding:5px 10px;
# 	background: #444;
# 	border-radius: 4px;
# 	white-space: pre-wrap;
# 	position:relative;
# 	color:white;
# }
# .copy-code-button{
# 	float:right;
# 	background:#333;
# 	color:white;
# 	border: none;
# 	margin: 0 0 0 10px;
# 	cursor: pointer;
# }
# p, li{
# 	max-width:700px;
# }
# .choices{
# 	display:flex;
# 	flex: 1 0 auto;
# }
# .choice-section{
# 	border:solid 1px #555;
# 	border-radius: 4px;
# 	min-width:300px;
# 	margin: 10px 15px 0 0;
# 	padding: 0 15px 15px 15px ;
# }
# .button{
# 	padding: 10px 15px;
# 	background:#333;
# 	border-radius: 4px;
# 	border:solid 1px #555;
# 	color:white;
# 	font-weight:bold;
# 	cursor:pointer;
# }
# .pill{
# 	padding:2px 4px;
# 	border-radius: 100px;
# 	background-color:#e65858;
# 	font-size:12px;
# 	font-weight:bold;
# 	margin: 0 15px;
# 	color:white;
# }
# </style>
# <details class="choice-section">
# ...

# %%
# !nvidia-smi -l 10
# Out:
# Wed Jul 14 05:24:57 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
